# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file1 = pd.read_excel('/home/aditya/yolov3/master/output_train/mAP_sheet.xlsx', sheet_name = [2,3,4,5])

# %%
for key in file1:
    df1 = file1[key]
    img1 = df1.plot.line(x='Epoch',y='mAP',legend=True)
    img1.set_xlim([0,60])
    img1.set_ylim([0,1])
    img2 = df1.plot.line(x='Epoch',y='Loss',legend=True)
    img2.set_xlim([0,60])
    img2.set_ylim([0,60])
